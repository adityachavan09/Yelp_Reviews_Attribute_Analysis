# %%
# !pip install bertopic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 59.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 14.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from bertopic import BERTopic

# %%
df = pd.read_csv('/content/drive/MyDrive/Text Project/data5.csv')

# %%
df = df.sample(10000)

# %%
docs = df["joined"].tolist()

# %%
docs[0:10]
# Out:
# ['great food tofu sweet taste good thery othrr selection',
#  'place masters gluttony like hitting lottery food words hardly explain rtm unique feel like youve stepped time favorite tos philly',
#  'food mojo fantastic love prosciutto salad great steaks sea bass crazy mean waitress working visit reason mojo star review sit outside avoid food worth',
#  'theres window south street orderingtake ate inside sure bistro confusing floor guess normal restaurant look need real updating delicious food got greek salad dressing yummy got hummus felafel delicious fresh food came quickly great lamb gyro chicken gyro plate comes riceveggies good portions tasted fresh highly recommend going',
#  'love restaurant fairmount staff friendly patient order food delicious ordered tsipoura mediterranean fish specials absolutely incredible best debone fish dont work disappointment kalamata martini didnt hit right food little pricey fairmount ave definitely worth',
# ...

# %%
docs = [str(element) for element in docs]

# %%
docs = [x for x in docs if x.lower() != "nan"]

# %%
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(docs)
# Out:
# 2023-11-27 22:57:09,688 - BERTopic - Embedding - Transforming documents to embeddings.
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# ...

# %%
freq = topic_model.get_topic_info(); freq.head(10)
# Out:
#    Topic  Count                             Name  \
# 0     -1   5194       -1_food_good_place_service
# 1      0    393           0_beer_bar_music_beers
# 2      1    378       1_pizza_crust_pizzas_slice
# 3      2    271          2_sushi_roll_rolls_tuna
# 4      3    241    3_shrimp_crab_oysters_seafood
# 5      4    179       4_burger_fries_burgers_bun
# 6      5    161    5_eggs_brunch_breakfast_toast
# 7      6    131       6_orleans_new_oysters_jazz
# 8      7    128      7_coffee_starbucks_shop_cup
# 9      8    128  8_philly_cheesesteak_genos_pats
#
#                                       Representation  \
# 0  [food, good, place, service, great, time, like...
# 1  [beer, bar, music, beers, drinks, great, place...
# 2  [pizza, crust, pizzas, slice, pepperoni, toppi...
# 3  [sushi, roll, rolls, tuna, quality, fish, temp...
# 4  [shrimp, crab, oysters, seafood, beach, crawfi...
# 5  [burger, fries, burgers, bun, good, place, bee...
# ...

# %%
freq.to_csv('topics.csv')

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_hierarchy(top_n_topics=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_barchart(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
